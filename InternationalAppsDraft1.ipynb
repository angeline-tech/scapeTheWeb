# %%
import requests
import lxml.html as lh
import pandas as pd
import re

# %%
url = 'https://en.wikipedia.org/wiki/Bernd_Leno'

def getNationalTeamTable(url):
    page = requests.get(url)
    doc = lh.fromstring(page.content)
    tables = doc.xpath('//table')
    for table in tables:
        captions = table.xpath('//caption')
        for caption in captions:
            text = caption.text_content()
            if "Appearances and goals by national team and year" in text:
                return table

# TODO: Better Look Up
def getAppsForPlayer(wiki_name):
    url = 'https://en.wikipedia.org/wiki/'+wiki_name
    table = getNationalTeamTable(url)
    if table:
        rows = table.xpath('//tr')
        i=0
        for row in rows:
            i=i+1
            if "Total" in row.text_content():
                if len(row) == 3:
                    total = row[1]
                    return int(total.text_content()), url
    print('Error Getting Apps for: ' + url)
    return -1 ,url

# %%
def getPlayerRows(url):
    playerRows = []
    page = requests.get(url)
    doc = lh.fromstring(page.content)
    rows = doc.xpath('//tr')
    for row in rows:
        if len(row) == 12:
            name_cell = row[3]
            nationality_cell = row[2]
            text = name_cell.text_content().strip()
            skip = text.isnumeric() or len(text) == 0 or text == 'Name'
            if not skip:
                playerRows.append((name_cell,nationality_cell))
    if len(playerRows) == 0:
        print('Error Getting Players from: ' + url)
    else:
        print('Jheeeze found {} players'.format(len(playerRows)))
    return playerRows
    
    
def getWikiLink(cell):
    links = list(cell.iterlinks())
    if len(links)==0:
        return 'ERROR'
    return links[0][2].replace('/wiki/','')


def getWikiDetails(cells):
    player = cells[0]
    country_cell = cells[1]
    display_name = player.text_content()
#     links = list(player.iterlinks())
#     wiki_name = links[0][2].replace('/wiki/','')
    return display_name, getWikiLink(player), getWikiLink(country_cell)

def addPlayerApps(name_tuple):
    display_name = name_tuple[0]
    wiki_name = name_tuple[1]
    country = name_tuple[2]
    (apps,url) = getAppsForPlayer(wiki_name)
    return display_name, wiki_name, country, apps, url

# %%
def addPlayerApps(name_tuple):
    display_name = name_tuple[0]
    wiki_name = name_tuple[1]
    country = name_tuple[2]
    (apps,url) = getAppsForPlayer(wiki_name)
    return display_name, wiki_name, country, apps, url

# %%
def getAppearanceArray(url):
    playerRows = getPlayerRows(url)
    linksArray = [getWikiDetails(player) for player in playerRows]
    appsArray = [addPlayerApps(names) for names in linksArray]
    return appsArray

# %%
def getTeams(url):
    teams = []
    page = requests.get(url)
    doc = lh.fromstring(page.content)
    rows = doc.xpath('//tr')
    for row in rows:
        if len(row) == 4:
            cell = row[0]
            text = cell.text_content().strip()
            skip = text == 'Team' or text == 'Rank' or text.isnumeric()
            if not skip:
                teams.append(cell)
    return teams


def addTeamToEachItem(player,teamName,squad_url):
    (display_name, wiki_name, country, apps, url) = player
    return teamName,squad_url,display_name, wiki_name, country, apps, url

# %%
def fuckedIt(name):
    return 'Fucked It','should be wiki link for'+name,'but Im weird', None, None, None, None

# %%
def getDataFrameForLeague(url):
    teams = getTeams(url)
    output = []
    for team in teams:
        teamDisplayName = team.text_content()
        wiki_name = getWikiLink(team)
        if wiki_name == 'ERROR':
            output = output.append(fuckedIt(teamDisplayName))
        else:
            squad_url = 'https://en.wikipedia.org/wiki/2019-20_'+wiki_name+'_season'
            print('Doing Look up for: '+ teamDisplayName)
            appearanceArray = getAppearanceArray(squad_url)
            updatedArray = [addTeamToEachItem(player,teamDisplayName,squad_url) for player in appearanceArray]
            output = output + updatedArray
    return pd.DataFrame(output, columns = ['teamName','squad_url','display_name', 'wiki_name', 'country', 'apps', 'url'])

# %%
url = 'https://en.wikipedia.org/wiki/2020%E2%80%9321_Premier_League#Teams'
data = getDataFrameForLeague(url)
print(len(data))
# Out:
# Doing Look up for: Arsenal
#
# Jheeeze found 32 players
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: The behavior of this method will change in future versions. Use specific 'len(elem)' or 'elem is not None' test instead.
# Error Getting Apps for: https://en.wikipedia.org/wiki/Kieran_Tierney
# Error Getting Apps for: https://en.wikipedia.org/wiki/Lucas_Torreira
# Error Getting Apps for: https://en.wikipedia.org/wiki/Rob_Holding
# Error Getting Apps for: https://en.wikipedia.org/wiki/Pablo_Mar%C3%AD
# Error Getting Apps for: https://en.wikipedia.org/wiki/Reiss_Nelson
# Error Getting Apps for: https://en.wikipedia.org/wiki/Emiliano_Mart%C3%ADnez
# Error Getting Apps for: https://en.wikipedia.org/wiki/Konstantinos_Mavropanos
# Error Getting Apps for: https://en.wikipedia.org/wiki/Joe_Willock
# Error Getting Apps for: https://en.wikipedia.org/wiki/Matteo_Guendouzi
# Error Getting Apps for: https://en.wikipedia.org/wiki/Eddie_Nketiah
# Error Getting Apps for: https://en.wikipedia.org/wiki/Emile_Smith_Rowe
# Error Getting Apps for: https://en.wikipedia.org/wiki/Matt_Macey
# Error Getting Apps for: https://en.wikipedia.org/wiki/Gabriel_Martinelli
# Error Getting Apps for: https://en.wikipedia.org/wiki/William_Saliba
# Doing Look up for: Aston Villa
#
# Error Getting Players from: https://en.wikipedia.org/wiki/2019-20_Aston_Villa_F.C._season
# Doing Look up for: Brighton & Hove Albion
#
# Jheeeze found 39 players
# Error Getting Apps for: https://en.wikipedia.org/wiki/Mathew_Ryan
# Error Getting Apps for: https://en.wikipedia.org/wiki/Jason_Steele_(footballer)
# Error Getting Apps for: https://en.wikipedia.org/wiki/David_Button
# Error Getting Apps for: https://en.wikipedia.org/wiki/Tariq_Lamptey
# Error Getting Apps for: https://en.wikipedia.org/wiki/Adam_Webster_(footballer,_born_1995)
# Error Getting Apps for: https://en.wikipedia.org/wiki/Ezequiel_Schelotto
# Error Getting Apps for: https://en.wikipedia.org/wiki/Mart%C3%ADn_Montoya
# Error Getting Apps for: https://en.wikipedia.org/wiki/Bernardo_Fernandes_da_Silva_Junior
# Error Getting Apps for: https://en.wikipedia.org/wiki/Dan_Burn
# Error Getting Apps for: https://en.wikipedia.org/wiki/Romaric_Yapi
# Error Getting Apps for: https://en.wikipedia.org/wiki/Archie_Davies
# Error Getting Apps for: https://en.wikipedia.org/wiki/Haydon_Roberts
# Error Getting Apps for: https://en.wikipedia.org/wiki/Dale_Stephens_(footballer)
# Error Getting Apps for: https://en.wikipedia.org/wiki/Yves_Bissouma
# Error Getting Apps for: https://en.wikipedia.org/wiki/Alexis_Mac_Allister
# Error Getting Apps for: https://en.wikipedia.org/wiki/Pascal_Gro%C3%9F
# Error Getting Apps for: https://en.wikipedia.org/wiki/Solly_March
# Error Getting Apps for: https://en.wikipedia.org/wiki/Taylor_Richards
# Error Getting Apps for: https://en.wikipedia.org/wiki/Alex_Cochrane_(footballer)
# Error Getting Apps for: https://en.wikipedia.org/wiki/Peter_Gwargis
# Error Getting Apps for: https://en.wikipedia.org/wiki/Ryan_Longman
# Error Getting Apps for: https://en.wikipedia.org/wiki/Jack_Spong_(footballer)
# Error Getting Apps for: https://en.wikipedia.org/wiki/Teddy_Jenks
# Error Getting Apps for: https://en.wikipedia.org/wiki/Neal_Maupay
# Error Getting Apps for: https://en.wikipedia.org/wiki/Alireza_Jahanbakhsh
# Error Getting Apps for: https://en.wikipedia.org/wiki/Glenn_Murray
# Error Getting Apps for: https://en.wikipedia.org/wiki/Jos%C3%A9_Izquierdo_(footballer,_born_1992)
# Error Getting Apps for: https://en.wikipedia.org/wiki/J%C3%BCrgen_Locadia
# Error Getting Apps for: https://en.wikipedia.org/wiki/Florin_Andone
# Error Getting Apps for: https://en.wikipedia.org/wiki/Leon_Balogun
# Error Getting Apps for: https://en.wikipedia.org/wiki/Tudor_B%C4%83lu%C8%9B%C4%83
# Doing Look up for: Burnley
#
# Error Getting Players from: https://en.wikipedia.org/wiki/2019-20_Burnley_F.C._season
# Doing Look up for: Chelsea
#
# Jheeeze found 1 players
# Error Getting Apps for: https://en.wikipedia.org/wiki/ERROR
# Doing Look up for: Crystal Palace
#
# Jheeeze found 27 players
# Error Getting Apps for: https://en.wikipedia.org/wiki/Wayne_Hennessey
# Error Getting Apps for: https://en.wikipedia.org/wiki/Stephen_Henderson_(footballer,_born_1988)
# Error Getting Apps for: https://en.wikipedia.org/wiki/Vicente_Guaita
# Error Getting Apps for: https://en.wikipedia.org/wiki/Joel_Ward_(footballer)
# Error Getting Apps for: https://en.wikipedia.org/wiki/Patrick_van_Aanholt
# Error Getting Apps for: https://en.wikipedia.org/wiki/James_Tomkins_(footballer)
# Error Getting Apps for: https://en.wikipedia.org/wiki/Scott_Dann
# Error Getting Apps for: https://en.wikipedia.org/wiki/Mamadou_Sakho
# Error Getting Apps for: https://en.wikipedia.org/wiki/Sam_Woods_(footballer)
# Error Getting Apps for: https://en.wikipedia.org/wiki/Tyrick_Mitchell
# Error Getting Apps for: https://en.wikipedia.org/wiki/Luka_Milivojevi%C4%87
# Error Getting Apps for: https://en.wikipedia.org/wiki/Cheikhou_Kouyat%C3%A9
# Error Getting Apps for: https://en.wikipedia.org/wiki/Jeffrey_Schlupp
# Error Getting Apps for: https://en.wikipedia.org/wiki/James_McArthur
# Error Getting Apps for: https://en.wikipedia.org/wiki/Brandon_Pierrick
# Error Getting Apps for: https://en.wikipedia.org/wiki/Ja%C3%AFro_Riedewald
# Error Getting Apps for: https://en.wikipedia.org/wiki/Jordan_Ayew
# Error Getting Apps for: https://en.wikipedia.org/wiki/Christian_Benteke
# Error Getting Apps for: https://en.wikipedia.org/wiki/Connor_Wickham
# Error Getting Apps for: https://en.wikipedia.org/wiki/Cenk_Tosun
# Error Getting Apps for: https://en.wikipedia.org/wiki/V%C3%ADctor_Camarasa
# Doing Look up for: Everton
#
# Jheeeze found 28 players
# Error Getting Apps for: https://en.wikipedia.org/wiki/Mason_Holgate
# Error Getting Apps for: https://en.wikipedia.org/wiki/Yerry_Mina
# Error Getting Apps for: https://en.wikipedia.org/wiki/Jarrad_Branthwaite
# Error Getting Apps for: https://en.wikipedia.org/wiki/Gylfi_Sigur%C3%B0sson
# Error Getting Apps for: https://en.wikipedia.org/wiki/Bernard_(footballer)
# Error Getting Apps for: https://en.wikipedia.org/wiki/Andr%C3%A9_Gomes
# Error Getting Apps for: https://en.wikipedia.org/wiki/Jean-Philippe_Gbamin
# Error Getting Apps for: https://en.wikipedia.org/wiki/Tom_Davies_(footballer,_born_1998)
# Error Getting Apps for: https://en.wikipedia.org/wiki/Anthony_Gordon_(footballer)
# Error Getting Apps for: https://en.wikipedia.org/wiki/Cenk_Tosun
# Error Getting Apps for: https://en.wikipedia.org/wiki/Cuco_Martina
# Error Getting Apps for: https://en.wikipedia.org/wiki/Yannick_Bolasie
# Doing Look up for: Fulham
# Error Getting Players from: https://en.wikipedia.org/wiki/2019-20_Fulham_F.C._season
# Doing Look up for: Leeds United
#
# Jheeeze found 29 players
# Error Getting Apps for: https://en.wikipedia.org/wiki/Illan_Meslier
# Error Getting Apps for: https://en.wikipedia.org/wiki/Kiko_Casilla
# Error Getting Apps for: https://en.wikipedia.org/wiki/Luke_Ayling
# Error Getting Apps for: https://en.wikipedia.org/wiki/Barry_Douglas
# Error Getting Apps for: https://en.wikipedia.org/wiki/Ben_White_(footballer)
# Error Getting Apps for: https://en.wikipedia.org/wiki/Liam_Cooper
# Error Getting Apps for: https://en.wikipedia.org/wiki/Gaetano_Berardi
# Error Getting Apps for: https://en.wikipedia.org/wiki/Pascal_Struijk
# Error Getting Apps for: https://en.wikipedia.org/wiki/Leif_Davis
# Error Getting Apps for: https://en.wikipedia.org/wiki/Oliver_Casey
# Error Getting Apps for: https://en.wikipedia.org/wiki/Adam_Forshaw
# Error Getting Apps for: https://en.wikipedia.org/wiki/Ian_Poveda
# Error Getting Apps for: https://en.wikipedia.org/wiki/H%C3%A9lder_Costa_(footballer)
# Error Getting Apps for: https://en.wikipedia.org/wiki/Jack_Harrison_(footballer,_born_1996)
# Error Getting Apps for: https://en.wikipedia.org/wiki/Robbie_Gotts
# Error Getting Apps for: https://en.wikipedia.org/wiki/Alfie_McCalmont
# Error Getting Apps for: https://en.wikipedia.org/wiki/Mateusz_Klich
# Error Getting Apps for: https://en.wikipedia.org/wiki/Mateusz_Bogusz
# Error Getting Apps for: https://en.wikipedia.org/wiki/Jamie_Shackleton
# Error Getting Apps for: https://en.wikipedia.org/wiki/Jordan_Stevens
# Error Getting Apps for: https://en.wikipedia.org/wiki/Patrick_Bamford
# Error Getting Apps for: https://en.wikipedia.org/wiki/Tyler_Roberts
# Error Getting Apps for: https://en.wikipedia.org/wiki/Jean-K%C3%A9vin_Augustin
# Error Getting Apps for: https://en.wikipedia.org/wiki/Eddie_Nketiah
# Error Getting Apps for: https://en.wikipedia.org/wiki/Jack_Clarke_(footballer,_born_2000)
# Doing Look up for: Leicester City
#
# Jheeeze found 35 players
# Error Getting Apps for: https://en.wikipedia.org/wiki/Kasper_Schmeichel
# Error Getting Apps for: https://en.wikipedia.org/wiki/James_Justin
# Error Getting Apps for: https://en.wikipedia.org/wiki/%C3%87a%C4%9Flar_S%C3%B6y%C3%BCnc%C3%BC
# Error Getting Apps for: https://en.wikipedia.org/wiki/Jonny_Evans
# Error Getting Apps for: https://en.wikipedia.org/wiki/Demarai_Gray
# Error Getting Apps for: https://en.wikipedia.org/wiki/Marc_Albrighton
# Error Getting Apps for: https://en.wikipedia.org/wiki/Islam_Slimani
# Error Getting Apps for: https://en.wikipedia.org/wiki/Filip_Benkovi%C4%87
# Error Getting Apps for: https://en.wikipedia.org/wiki/Ayoze_P%C3%A9rez
# Error Getting Apps for: https://en.wikipedia.org/wiki/Hamza_Choudhury
# Error Getting Apps for: https://en.wikipedia.org/wiki/Ricardo_Pereira_(footballer,_born_1993)
# Error Getting Apps for: https://en.wikipedia.org/wiki/Matty_James
# Error Getting Apps for: https://en.wikipedia.org/wiki/Adrien_Silva
# Error Getting Apps for: https://en.wikipedia.org/wiki/Nampalys_Mendy
# Error Getting Apps for: https://en.wikipedia.org/wiki/Dennis_Praet
# Error Getting Apps for: https://en.wikipedia.org/wiki/Fousseni_Diabat%C3%A9
# Error Getting Apps for: https://en.wikipedia.org/wiki/Christian_Fuchs
# Error Getting Apps for: https://en.wikipedia.org/wiki/Ryan_Bennett_(footballer)
# Error Getting Apps for: https://en.wikipedia.org/wiki/Rachid_Ghezzal
# Error Getting Apps for: https://en.wikipedia.org/wiki/Eldin_Jakupovi%C4%87
# Error Getting Apps for: https://en.wikipedia.org/wiki/Darnell_Johnson
# Error Getting Apps for: https://en.wikipedia.org/wiki/George_Hirst_(footballer)
# Error Getting Apps for: https://en.wikipedia.org/wiki/Kiernan_Dewsbury-Hall
# Error Getting Apps for: https://en.wikipedia.org/wiki/Luke_Thomas_(footballer,_born_2001)
# Doing Look up for: Liverpool
#
# Jheeeze found 1 players
# Error Getting Apps for: https://en.wikipedia.org/wiki/ERROR
# Doing Look up for: Manchester City
#
# Error Getting Players from: https://en.wikipedia.org/wiki/2019-20_Manchester_City_F.C._season
# Doing Look up for: Manchester United
#
# Jheeeze found 1 players
# Error Getting Apps for: https://en.wikipedia.org/wiki/ERROR
# Doing Look up for: Newcastle United
#
# Jheeeze found 32 players
# Error Getting Apps for: https://en.wikipedia.org/wiki/Rob_Elliot
# Error Getting Apps for: https://en.wikipedia.org/wiki/Karl_Darlow
# Error Getting Apps for: https://en.wikipedia.org/wiki/Paul_Dummett
# Error Getting Apps for: https://en.wikipedia.org/wiki/Fabian_Sch%C3%A4r
# Error Getting Apps for: https://en.wikipedia.org/wiki/Jamaal_Lascelles
# Error Getting Apps for: https://en.wikipedia.org/wiki/Emil_Krafth
# Error Getting Apps for: https://en.wikipedia.org/wiki/Federico_Fern%C3%A1ndez_(footballer)
# Error Getting Apps for: https://en.wikipedia.org/wiki/Javier_Manquillo
# Error Getting Apps for: https://en.wikipedia.org/wiki/Florian_Lejeune
# Error Getting Apps for: https://en.wikipedia.org/wiki/DeAndre_Yedlin
# Error Getting Apps for: https://en.wikipedia.org/wiki/Jamie_Sterry
# Error Getting Apps for: https://en.wikipedia.org/wiki/Allan_Saint-Maximin
# Error Getting Apps for: https://en.wikipedia.org/wiki/Isaac_Hayden
# Error Getting Apps for: https://en.wikipedia.org/wiki/Valentino_Lazaro
# Error Getting Apps for: https://en.wikipedia.org/wiki/Henri_Saivet
# Error Getting Apps for: https://en.wikipedia.org/wiki/Christian_Atsu
# Error Getting Apps for: https://en.wikipedia.org/wiki/Sean_Longstaff
# Error Getting Apps for: https://en.wikipedia.org/wiki/Nabil_Bentaleb
# Error Getting Apps for: https://en.wikipedia.org/wiki/Matty_Longstaff
# Error Getting Apps for: https://en.wikipedia.org/wiki/Joelinton
# Error Getting Apps for: https://en.wikipedia.org/wiki/Dwight_Gayle
# Error Getting Apps for: https://en.wikipedia.org/wiki/Thomas_Allan_(footballer,_born_1999)
# Error Getting Apps for: https://en.wikipedia.org/wiki/Ki_Sung-yueng
# Error Getting Apps for: https://en.wikipedia.org/wiki/Jetro_Willems
# Doing Look up for: Sheffield United
#
# Jheeeze found 30 players
# Error Getting Apps for: https://en.wikipedia.org/wiki/Michael_Verrips
# Error Getting Apps for: https://en.wikipedia.org/wiki/Simon_Moore_(footballer)
# Error Getting Apps for: https://en.wikipedia.org/wiki/George_Baldock
# Error Getting Apps for: https://en.wikipedia.org/wiki/Jack_O%27Connell_(English_footballer)
# Error Getting Apps for: https://en.wikipedia.org/wiki/Chris_Basham
# Error Getting Apps for: https://en.wikipedia.org/wiki/Kieron_Freeman
# Error Getting Apps for: https://en.wikipedia.org/wiki/Jack_Robinson_(footballer,_born_1993)
# Error Getting Apps for: https://en.wikipedia.org/wiki/Panagiotis_Retsos
# Error Getting Apps for: https://en.wikipedia.org/wiki/John_Lundstram
# Error Getting Apps for: https://en.wikipedia.org/wiki/Luke_Freeman
# Error Getting Apps for: https://en.wikipedia.org/wiki/Ben_Osborn
# Error Getting Apps for: https://en.wikipedia.org/wiki/Muhamed_Be%C5%A1i%C4%87
# Error Getting Apps for: https://en.wikipedia.org/wiki/Sander_Berge
# Error Getting Apps for: https://en.wikipedia.org/wiki/Oli_McBurnie
# Error Getting Apps for: https://en.wikipedia.org/wiki/Billy_Sharp
# Error Getting Apps for: https://en.wikipedia.org/wiki/Lys_Mousset
# Error Getting Apps for: https://en.wikipedia.org/wiki/Leon_Clarke
# Error Getting Apps for: https://en.wikipedia.org/wiki/Richairo_Zivkovic
# Error Getting Apps for: https://en.wikipedia.org/wiki/Kean_Bryan
# Error Getting Apps for: https://en.wikipedia.org/wiki/Richard_Stearman
# Doing Look up for: Southampton
#
# Error Getting Players from: https://en.wikipedia.org/wiki/2019-20_Southampton_F.C._season
# Doing Look up for: Tottenham Hotspur
#
# Error Getting Players from: https://en.wikipedia.org/wiki/2019-20_Tottenham_Hotspur_F.C._season
# Doing Look up for: West Bromwich Albion
#
# Jheeeze found 29 players
# Error Getting Apps for: https://en.wikipedia.org/wiki/Sam_Johnstone
# Error Getting Apps for: https://en.wikipedia.org/wiki/Darnell_Furlong
# Error Getting Apps for: https://en.wikipedia.org/wiki/Hal_Robson-Kanu
# Error Getting Apps for: https://en.wikipedia.org/wiki/Kyle_Bartley
# Error Getting Apps for: https://en.wikipedia.org/wiki/Semi_Ajayi
# Error Getting Apps for: https://en.wikipedia.org/wiki/Filip_Krovinovi%C4%87
# Error Getting Apps for: https://en.wikipedia.org/wiki/Kenneth_Zohore
# Error Getting Apps for: https://en.wikipedia.org/wiki/Matheus_Fellipe_Costa_Pereira
# Error Getting Apps for: https://en.wikipedia.org/wiki/Conor_Townsend
# Error Getting Apps for: https://en.wikipedia.org/wiki/Charlie_Austin
# Error Getting Apps for: https://en.wikipedia.org/wiki/Rekeem_Harper
# Error Getting Apps for: https://en.wikipedia.org/wiki/Gareth_Barry
# Error Getting Apps for: https://en.wikipedia.org/wiki/Kyle_Edwards_(footballer)
# Error Getting Apps for: https://en.wikipedia.org/wiki/Jonathan_Bond
# Error Getting Apps for: https://en.wikipedia.org/wiki/Grady_Diangana
# Error Getting Apps for: https://en.wikipedia.org/wiki/Rayhaan_Tulloch
# Error Getting Apps for: https://en.wikipedia.org/wiki/Jack_Fitzwater
# Error Getting Apps for: https://en.wikipedia.org/wiki/Nathan_Ferguson_(footballer,_born_2000)
# Error Getting Apps for: https://en.wikipedia.org/wiki/Saul_Shotton
# Doing Look up for: West Ham United
#
# Jheeeze found 30 players
# Error Getting Apps for: https://en.wikipedia.org/wiki/David_Martin_(footballer,_born_1986)
# Error Getting Apps for: https://en.wikipedia.org/wiki/Issa_Diop_(footballer)
# Error Getting Apps for: https://en.wikipedia.org/wiki/Ryan_Fredericks
# Error Getting Apps for: https://en.wikipedia.org/wiki/Ben_Johnson_(footballer,_born_2000)
# Error Getting Apps for: https://en.wikipedia.org/wiki/Mark_Noble
# Error Getting Apps for: https://en.wikipedia.org/wiki/Pablo_Fornals
# Error Getting Apps for: https://en.wikipedia.org/wiki/Tom%C3%A1%C5%A1_Sou%C4%8Dek
# Error Getting Apps for: https://en.wikipedia.org/wiki/Jarrod_Bowen
# Error Getting Apps for: https://en.wikipedia.org/wiki/Albian_Ajeti
# Error Getting Apps for: https://en.wikipedia.org/wiki/Michail_Antonio
# Error Getting Apps for: https://en.wikipedia.org/wiki/Roberto_Jim%C3%A9nez_Gago
# Error Getting Apps for: https://en.wikipedia.org/wiki/Nathan_Holland
# Error Getting Apps for: https://en.wikipedia.org/wiki/Jeremy_Ngakia
# Error Getting Apps for: https://en.wikipedia.org/wiki/Conor_Coventry
# Doing Look up for: Wolverhampton Wanderers
#
# Error Getting Players from: https://en.wikipedia.org/wiki/2019-20_Wolverhampton_Wanderers_F.C._season
# 314

# %%
def writeDataToFile(df,fileName):
    df.to_csv(fileName,index=False)
    print(df.head())

# %%
writeDataToFile(data,"PremSample.csv")

# %%
import csv

with open('leagues.csv', newline='') as csvfile:
    leagueList = list(csv.reader(csvfile))

print(leagueList)
# Out:
# [['SPAIN', 'https://en.wikipedia.org/wiki/2019%E2%80%9320_La_Liga'], ['ENGLAND', 'https://en.wikipedia.org/wiki/2019%E2%80%9320_Premier_League'], ['GERMANY', 'https://en.wikipedia.org/wiki/2019%E2%80%9320_Bundesliga'], ['ITALY', 'https://en.wikipedia.org/wiki/2019%E2%80%9320_Serie_A'], ['FRANCE', 'https://en.wikipedia.org/wiki/2019%E2%80%9320_Ligue_1'], ['PORTUGAL', 'https://en.wikipedia.org/wiki/2019%E2%80%9320_Primeira_Liga'], ['RUSSIA', 'https://en.wikipedia.org/wiki/2019%E2%80%9320_Russian_Premier_League'], ['BELGIUM', 'https://en.wikipedia.org/wiki/2019%E2%80%9320_Belgian_First_Division_A'], ['UKRAINE', 'https://en.wikipedia.org/wiki/2019%E2%80%9320_Ukrainian_Premier_League'], ['NETHERLANDS', 'https://en.wikipedia.org/wiki/2019%E2%80%9320_Eredivisie'], ['TURKEY', 'https://en.wikipedia.org/wiki/2019%E2%80%9320_S%C3%BCper_Lig'], ['AUSTRIA', 'https://en.wikipedia.org/wiki/2019%E2%80%9320_Austrian_Football_Bundesliga'], ['DENMARK', 'https://en.wikipedia.org/wiki/2019%E2%80%9320_Danish_Superliga'], ['SCOTLAND', 'https://en.wikipedia.org/wiki/2019%E2%80%9320_Scottish_Premiership'], ['CZECH', 'EPUBLIC', 'https://en.wikipedia.org/wiki/2019%E2%80%9320_Czech_First_League'], ['CYPRUS', 'https://en.wikipedia.org/wiki/2019%E2%80%9320_Cypriot_First_Division'], ['SWITZERLAND', 'https://en.wikipedia.org/wiki/2019%E2%80%9320_Swiss_Super_League'], ['GREECE', 'https://en.wikipedia.org/wiki/2019%E2%80%9320_Super_League_Greece'], ['SERBIA', 'https://en.wikipedia.org/wiki/2019%E2%80%9320_Serbian_SuperLiga'], ['CROATIA', 'https://en.wikipedia.org/wiki/2019%E2%80%9320_Croatian_First_Football_League'], ['SWEDEN', 'https://en.wikipedia.org/wiki/2019_Allsvenskan'], ['ISRAEL', 'https://en.wikipedia.org/wiki/2019%E2%80%9320_Israeli_Premier_League'], ['NORWAY', 'https://en.wikipedia.org/wiki/2019_Eliteserien'], ['HUNGARY', 'https://en.wikipedia.org/wiki/2019%E2%80%9320_Nemzeti_Bajnoks%C3%A1g_I'], ['BRAZIL', 'https://en.wikipedia.org/wiki/2019_Campeonato_Brasileiro_S%C3%A9rie_A'], ['URUGUAY', 'https://en.wikipedia.org/wiki/2019_Uruguayan_Primera_Divisi%C3%B3n_season'], ['ARGENTINA', 'https://en.wikipedia.org/wiki/2019%E2%80%9320_Argentine_Primera_Divisi%C3%B3n'], ['COLOMBIA', 'https://en.wikipedia.org/wiki/2019_Categor%C3%ADa_Primera_A_season'], ['MEXICO', 'https://en.wikipedia.org/wiki/2019%E2%80%9320_Liga_MX_season'], ['CHILE', 'https://en.wikipedia.org/wiki/2019_Chilean_Primera_Divisi%C3%B3n'], ['PERU', 'https://en.wikipedia.org/wiki/2019_Liga_1_(Peru)'], ['USA', 'https://en.wikipedia.org/wiki/2019_Major_League_Soccer_season'], ['CHINA', 'https://en.wikipedia.org/wiki/2019_Chinese_Super_League'], ['JAPAN', 'https://en.wikipedia.org/wiki/2019_in_Japanese_football'], ['SOUTH', 'OREA', 'https://en.wikipedia.org/wiki/2019_K_League_1'], ['QATAR', 'https://en.wikipedia.org/wiki/2019%E2%80%9320_Qatar_Stars_League'], ['SAUDI', 'RABIA', 'https://en.wikipedia.org/wiki/2019%E2%80%9320_Saudi_Professional_League'], ['AUSTRALIA', 'https://en.wikipedia.org/wiki/2019%E2%80%9320_A-League'], ['INDIA', 'https://en.wikipedia.org/wiki/2019%E2%80%9320_Indian_Super_League_season'], ['EGYPT', 'https://en.wikipedia.org/wiki/2019%E2%80%9320_Egyptian_Premier_League'], ['TUNISIA', 'https://en.wikipedia.org/wiki/2019%E2%80%9320_Tunisian_Ligue_Professionnelle_1'], ['ALGERIA', 'https://en.wikipedia.org/wiki/2019%E2%80%9320_in_Algerian_football'], ['GHANA', 'https://en.wikipedia.org/wiki/2019%E2%80%9320_Ghana_Premier_League']]
